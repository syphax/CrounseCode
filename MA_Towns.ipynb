# %% [markdown]
# <a href="https://colab.research.google.com/github/syphax/CrounseCode/blob/master/MA_Towns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt

from shapely.geometry import Polygon, LineString

# %%
path = os.path.join('drive', 'MyDrive', 'Data', 'Mass GIS', 'townssurvey_shp')

df_towns_p = gpd.read_file(os.path.join(path, 'TOWNSSURVEY_POLY.shp'))

# %%
df_towns_p.plot(color='blue', edgecolor='black')

plt.show()

# %%
df_local = df_towns_p[df_towns_p['TOWN'].isin(['CONCORD', 'ACTON', 'LINCOLN'])]

# %%
df_local.plot(color='blue', edgecolor='black')

plt.show()

# %%
# Decompose polygons to edges

def polygon_to_segments(polygon):
    """Converts a polygon to its constituent line segments."""
    exterior_coords = polygon.exterior.coords
    return [LineString([exterior_coords[i], exterior_coords[i + 1]]) for i in range(len(exterior_coords) - 1)]

def blow_up_polygons(_df):

# New DataFrame to store segments
  _segments_gdf = gpd.GeoDataFrame(columns=_df.columns)

  for index, row in _df.iterrows():
      # Get segments from the polygon
      segments = polygon_to_segments(row['geometry'])

      # Create a new row for each segment
      for segment in segments:
          new_row = row.copy()
          new_row['geometry'] = segment
          _segments_gdf = _segments_gdf.append(new_row, ignore_index=True)

  return _segments_gdf

# %%
df_segs = blow_up_polygons(df_local)
# Out:
# <ipython-input-20-8d342b5350be>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   _segments_gdf = _segments_gdf.append(new_row, ignore_index=True)

# %%
df_segs
# Out:
#         TOWN TOWN_ID POP1980 POP1990 POP2000 POPCH90_00 TYPE ISLAND  \
# 0    LINCOLN     157    7464    7666    8056        390    T      0
# 1    LINCOLN     157    7464    7666    8056        390    T      0
# 2    LINCOLN     157    7464    7666    8056        390    T      0
# 3    LINCOLN     157    7464    7666    8056        390    T      0
# 4    LINCOLN     157    7464    7666    8056        390    T      0
# ..       ...     ...     ...     ...     ...        ...  ...    ...
# 301  CONCORD      67   16455   17076   16993        -83    T      0
# 302  CONCORD      67   16455   17076   16993        -83    T      0
# 303  CONCORD      67   16455   17076   16993        -83    T      0
# 304  CONCORD      67   16455   17076   16993        -83    T      0
# 305  CONCORD      67   16455   17076   16993        -83    T      0
#
#     COASTAL_PO FOURCOLOR  ...  FIPS_MCD FIPS_COUNT      ACRES SQUARE_MIL  \
# 0           NO         2  ...  25017120         17   9587.925     14.981
# 1           NO         2  ...  25017120         17   9587.925     14.981
# 2           NO         2  ...  25017120         17   9587.925     14.981
# 3           NO         2  ...  25017120         17   9587.925     14.981
# 4           NO         2  ...  25017120         17   9587.925     14.981
# ..         ...       ...  ...       ...        ...        ...        ...
# 301         NO         3  ...  25017070         17  16532.471     25.832
# 302         NO         3  ...  25017070         17  16532.471     25.832
# 303         NO         3  ...  25017070         17  16532.471     25.832
# 304         NO         3  ...  25017070         17  16532.471     25.832
# 305         NO         3  ...  25017070         17  16532.471     25.832
#
#     POP2010  POPCH00_10  POPCH80_90    SHAPE_AREA     SHAPE_LEN  \
# 0      6362       -1694         202  3.880094e+07  28930.007681
# 1      6362       -1694         202  3.880094e+07  28930.007681
# 2      6362       -1694         202  3.880094e+07  28930.007681
# 3      6362       -1694         202  3.880094e+07  28930.007681
# 4      6362       -1694         202  3.880094e+07  28930.007681
# ..      ...         ...         ...           ...           ...
# 301   17668         675         621  6.690456e+07  36342.971523
# 302   17668         675         621  6.690456e+07  36342.971523
# 303   17668         675         621  6.690456e+07  36342.971523
# 304   17668         675         621  6.690456e+07  36342.971523
# 305   17668         675         621  6.690456e+07  36342.971523
#
#                                               geometry
# 0    LINESTRING (218695.742 912155.495, 219003.983 ...
# 1    LINESTRING (219003.983 910022.385, 219091.822 ...
# 2    LINESTRING (219091.822 909653.285, 219232.193 ...
# 3    LINESTRING (219232.193 908906.695, 219243.102 ...
# 4    LINESTRING (219243.102 908848.105, 219155.852 ...
# ..                                                 ...
# 301  LINESTRING (210886.422 906978.875, 205727.133 ...
# 302  LINESTRING (205727.133 909604.155, 209456.373 ...
# 303  LINESTRING (209456.373 917108.875, 212035.943 ...
# 304  LINESTRING (212035.943 916940.955, 214675.682 ...
# 305  LINESTRING (214675.682 916893.525, 214996.712 ...
#
# [306 rows x 23 columns]

# %%
df_segs[df_segs['TOWN'].isin(['CONCORD', 'ACTON'])]
# Out:
#         TOWN TOWN_ID POP1980 POP1990 POP2000 POPCH90_00 TYPE ISLAND  \
# 127    ACTON       2   17672   17872   20331       2459    T      0
# 128    ACTON       2   17672   17872   20331       2459    T      0
# 129    ACTON       2   17672   17872   20331       2459    T      0
# 130    ACTON       2   17672   17872   20331       2459    T      0
# 131    ACTON       2   17672   17872   20331       2459    T      0
# ..       ...     ...     ...     ...     ...        ...  ...    ...
# 301  CONCORD      67   16455   17076   16993        -83    T      0
# 302  CONCORD      67   16455   17076   16993        -83    T      0
# 303  CONCORD      67   16455   17076   16993        -83    T      0
# 304  CONCORD      67   16455   17076   16993        -83    T      0
# 305  CONCORD      67   16455   17076   16993        -83    T      0
#
#     COASTAL_PO FOURCOLOR  ...  FIPS_MCD FIPS_COUNT      ACRES SQUARE_MIL  \
# 127         NO         2  ...  25017005         17  12988.988     20.295
# 128         NO         2  ...  25017005         17  12988.988     20.295
# 129         NO         2  ...  25017005         17  12988.988     20.295
# 130         NO         2  ...  25017005         17  12988.988     20.295
# 131         NO         2  ...  25017005         17  12988.988     20.295
# ..         ...       ...  ...       ...        ...        ...        ...
# 301         NO         3  ...  25017070         17  16532.471     25.832
# 302         NO         3  ...  25017070         17  16532.471     25.832
# 303         NO         3  ...  25017070         17  16532.471     25.832
# 304         NO         3  ...  25017070         17  16532.471     25.832
# 305         NO         3  ...  25017070         17  16532.471     25.832
#
#     POP2010  POPCH00_10  POPCH80_90    SHAPE_AREA     SHAPE_LEN  \
# 127   21924        1593         200  5.256453e+07  30789.187913
# 128   21924        1593         200  5.256453e+07  30789.187913
# 129   21924        1593         200  5.256453e+07  30789.187913
# 130   21924        1593         200  5.256453e+07  30789.187913
# 131   21924        1593         200  5.256453e+07  30789.187913
# ..      ...         ...         ...           ...           ...
# 301   17668         675         621  6.690456e+07  36342.971523
# 302   17668         675         621  6.690456e+07  36342.971523
# 303   17668         675         621  6.690456e+07  36342.971523
# 304   17668         675         621  6.690456e+07  36342.971523
# 305   17668         675         621  6.690456e+07  36342.971523
#
#                                               geometry
# 127  LINESTRING (209456.373 917108.875, 205727.133 ...
# 128  LINESTRING (205727.133 909604.155, 202934.422 ...
# 129  LINESTRING (202934.422 911088.745, 200119.502 ...
# 130  LINESTRING (200119.502 912582.715, 202175.852 ...
# 131  LINESTRING (202175.852 916626.615, 204607.352 ...
# ..                                                 ...
# 301  LINESTRING (210886.422 906978.875, 205727.133 ...
# 302  LINESTRING (205727.133 909604.155, 209456.373 ...
# 303  LINESTRING (209456.373 917108.875, 212035.943 ...
# 304  LINESTRING (212035.943 916940.955, 214675.682 ...
# 305  LINESTRING (214675.682 916893.525, 214996.712 ...
#
# [179 rows x 23 columns]

# %%
# Out:
# <LINESTRING (218695.742 912155.495, 219003.983 910022.385)>
