# %%
import os
import time
import re
from PIL import Image
from PIL.ExifTags import TAGS

# %%
def rename_photos(directory):
    """Renames photos starting with 'P' using their metadata timestamp."""

    for filename in os.listdir(directory):
        if filename.startswith('P') and filename.lower().endswith(('.jpg', '.jpeg', '.png')):  # Case-insensitive check for image extensions
            filepath = os.path.join(directory, filename)
            try:
                img = Image.open(filepath)
                exif_data = img._getexif() 
                
                if exif_data:
                    # Get the DateTimeOriginal tag (36867)
                    datetime_str = exif_data.get(36867)
                    if datetime_str:
                        # Parse the EXIF datetime string (yyyy:mm:dd hh:mm:ss)
                        datetime_object = time.strptime(datetime_str, "%Y:%m:%d %H:%M:%S")
                        new_filename = time.strftime("%Y-%m-%d %H.%M.%S.jpg", datetime_object)   # Rename to  yyyy-mm-dd hh.mm.ss.jpg

                        new_filepath = os.path.join(directory, new_filename)

                        if not os.path.exists(new_filepath):  # Avoid overwriting existing files
                            os.rename(filepath, new_filepath)
                            print(f"Renamed '{filename}' to '{new_filename}'")
                        else:
                            # Handle filename collisions by appending a counter 
                            i = 1
                            while os.path.exists(new_filepath):
                                base, ext = os.path.splitext(new_filename)
                                new_filename = f"{base}_{i}{ext}"
                                new_filepath = os.path.join(directory, new_filename)
                                i += 1
                            os.rename(filepath, new_filepath)
                            print(f"Renamed '{filename}' to '{new_filename}' (Collision handled)")
                    else:
                        print(f"Skipping '{filename}' - No DateTimeOriginal metadata found.")
                else:
                    print(f"Skipping '{filename}' - No EXIF data found.")
            except Exception as e:  # Handle potential errors like invalid image files
                print(f"Error processing '{filename}': {e}")

# %%
p = '/Users/bcc/Google Drive/My Drive/CCXC/2024 CCXC Pictures'

rename_photos(p)
# Out:
# Renamed 'P1110498.JPG' to '2024-10-25 14.03.01.jpg'
# Renamed 'P1110856.JPG' to '2024-10-25 17.02.33.jpg'
# Renamed 'P1110842.JPG' to '2024-10-25 15.29.22.jpg'
# Renamed 'P1110659.JPG' to '2024-10-25 14.14.56.jpg'
# Renamed 'P1110671.JPG' to '2024-10-25 14.16.36.jpg'
# Renamed 'P1110665.JPG' to '2024-10-25 14.16.23.jpg'
# Renamed 'P1110739.JPG' to '2024-10-25 14.20.46.jpg'
# Renamed 'P1110705.JPG' to '2024-10-25 14.18.33.jpg'
# Renamed 'P1110507.JPG' to '2024-10-25 14.03.11.jpg'
# Renamed 'P1110513.JPG' to '2024-10-25 14.03.31.jpg'
# Renamed 'P1110512.JPG' to '2024-10-25 14.03.25.jpg'
# Renamed 'P1110506.JPG' to '2024-10-25 14.03.11_1.jpg' (Collision handled)
# Renamed 'P1110704.JPG' to '2024-10-25 14.17.45.jpg'
# Renamed 'P1110738.JPG' to '2024-10-25 14.20.46_1.jpg' (Collision handled)
# Renamed 'P1110664.JPG' to '2024-10-25 14.16.23_1.jpg' (Collision handled)
# Renamed 'P1110670.JPG' to '2024-10-25 14.16.31.jpg'
# Renamed 'P1110658.JPG' to '2024-10-25 14.14.56_1.jpg' (Collision handled)
# Renamed 'P1110843.JPG' to '2024-10-25 15.29.23.jpg'
# Renamed 'P1110499.JPG' to '2024-10-25 14.03.01_1.jpg' (Collision handled)
# Renamed 'P1110841.JPG' to '2024-10-25 15.29.22_1.jpg' (Collision handled)
# Renamed 'P1110699.JPG' to '2024-10-25 14.17.37.jpg'
# Renamed 'P1110855.JPG' to '2024-10-25 17.02.23.jpg'
# Renamed 'P1110666.JPG' to '2024-10-25 14.16.30.jpg'
# Renamed 'P1110672.JPG' to '2024-10-25 14.16.36_1.jpg' (Collision handled)
# Renamed 'P1110706.JPG' to '2024-10-25 14.18.33_1.jpg' (Collision handled)
# Renamed 'P1110538.JPG' to '2024-10-25 14.04.22.jpg'
# Renamed 'P1110510.JPG' to '2024-10-25 14.03.11_1_2.jpg' (Collision handled)
# Renamed 'P1110504.JPG' to '2024-10-25 14.03.09.jpg'
# Renamed 'P1110505.JPG' to '2024-10-25 14.03.09_1.jpg' (Collision handled)
# Renamed 'P1110511.JPG' to '2024-10-25 14.03.12.jpg'
# Renamed 'P1110539.JPG' to '2024-10-25 14.04.22_1.jpg' (Collision handled)
# Renamed 'P1110707.JPG' to '2024-10-25 14.18.33_1_2.jpg' (Collision handled)
# Renamed 'P1110673.JPG' to '2024-10-25 14.16.36_1_2.jpg' (Collision handled)
# Renamed 'P1110667.JPG' to '2024-10-25 14.16.30_1.jpg' (Collision handled)
# Renamed 'P1110854.JPG' to '2024-10-25 16.54.29.jpg'
# Renamed 'P1110698.JPG' to '2024-10-25 14.17.37_1.jpg' (Collision handled)
# Renamed 'P1110840.JPG' to '2024-10-25 15.29.22_1_2.jpg' (Collision handled)
# Renamed 'P1110844.JPG' to '2024-10-25 16.46.19.jpg'
# Renamed 'P1110850.JPG' to '2024-10-25 16.54.09.jpg'
# Renamed 'P1110688.JPG' to '2024-10-25 14.16.57.jpg'
# Renamed 'P1110663.JPG' to '2024-10-25 14.16.23_1_2.jpg' (Collision handled)
# Renamed 'P1110677.JPG' to '2024-10-25 14.16.45.jpg'
# Renamed 'P1110717.JPG' to '2024-10-25 14.18.51.jpg'
# Renamed 'P1110703.JPG' to '2024-10-25 14.17.45_1.jpg' (Collision handled)
# Renamed 'P1110515.JPG' to '2024-10-25 14.03.31_1.jpg' (Collision handled)
# Renamed 'P1110501.JPG' to '2024-10-25 14.03.01_1_2.jpg' (Collision handled)
# Renamed 'P1110529.JPG' to '2024-10-25 14.03.58.jpg'
# Renamed 'P1110528.JPG' to '2024-10-25 14.03.57.jpg'
# Renamed 'P1110500.JPG' to '2024-10-25 14.03.01_1_2_3.jpg' (Collision handled)
# Renamed 'P1110514.JPG' to '2024-10-25 14.03.31_1_2.jpg' (Collision handled)
# Renamed 'P1110702.JPG' to '2024-10-25 14.17.44.jpg'
# Renamed 'P1110716.JPG' to '2024-10-25 14.18.51_1.jpg' (Collision handled)
# Renamed 'P1110676.JPG' to '2024-10-25 14.16.37.jpg'
# Renamed 'P1110662.JPG' to '2024-10-25 14.16.22.jpg'
# Renamed 'P1110689.JPG' to '2024-10-25 14.16.57_1.jpg' (Collision handled)
# Renamed 'P1110851.JPG' to '2024-10-25 16.54.13.jpg'
# Renamed 'P1110845.JPG' to '2024-10-25 16.46.21.jpg'
# Renamed 'P1110853.JPG' to '2024-10-25 16.54.24.jpg'
# Renamed 'P1110847.JPG' to '2024-10-25 16.46.26.jpg'
# Renamed 'P1110674.JPG' to '2024-10-25 14.16.36_1_2_3.jpg' (Collision handled)
# Renamed 'P1110660.JPG' to '2024-10-25 14.14.56_1_2.jpg' (Collision handled)
# Renamed 'P1110648.JPG' to '2024-10-25 14.13.35.jpg'
# Renamed 'P1110700.JPG' to '2024-10-25 14.17.37_1_2.jpg' (Collision handled)
# Renamed 'P1110714.JPG' to '2024-10-25 14.18.51_1_2.jpg' (Collision handled)
# Renamed 'P1110728.JPG' to '2024-10-25 14.20.07.jpg'
# Renamed 'P1110502.JPG' to '2024-10-25 14.03.01_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110516.JPG' to '2024-10-25 14.03.31_1_2_3.jpg' (Collision handled)
# Renamed 'P1110517.JPG' to '2024-10-25 14.03.34.jpg'
# Renamed 'P1110503.JPG' to '2024-10-25 14.03.07.jpg'
# Renamed 'P1110729.JPG' to '2024-10-25 14.20.07_1.jpg' (Collision handled)
# Renamed 'P1110715.JPG' to '2024-10-25 14.18.51_1_2_3.jpg' (Collision handled)
# Renamed 'P1110701.JPG' to '2024-10-25 14.17.44_1.jpg' (Collision handled)
# Renamed 'P1110649.JPG' to '2024-10-25 14.13.36.jpg'
# Renamed 'P1110661.JPG' to '2024-10-25 14.16.22_1.jpg' (Collision handled)
# Renamed 'P1110675.JPG' to '2024-10-25 14.16.37_1.jpg' (Collision handled)
# Renamed 'P1110846.JPG' to '2024-10-25 16.46.23.jpg'
# Renamed 'P1110852.JPG' to '2024-10-25 16.54.17.jpg'
# Renamed 'P1110835.JPG' to '2024-10-25 15.29.20.jpg'
# Renamed 'P1110821.JPG' to '2024-10-25 15.23.51.jpg'
# Renamed 'P1110612.JPG' to '2024-10-25 14.12.05.jpg'
# Renamed 'P1110606.JPG' to '2024-10-25 14.10.55.jpg'
# Renamed 'P1110799.JPG' to '2024-10-25 14.23.14.jpg'
# Renamed 'P1110766.JPG' to '2024-10-25 14.22.00.jpg'
# Renamed 'P1110772.JPG' to '2024-10-25 14.22.08.jpg'
# Renamed 'P1110564.JPG' to '2024-10-25 14.09.08.jpg'
# Renamed 'P1110570.JPG' to '2024-10-25 14.09.15.jpg'
# Renamed 'P1110571.JPG' to '2024-10-25 14.09.15_1.jpg' (Collision handled)
# Renamed 'P1110565.JPG' to '2024-10-25 14.09.08_1.jpg' (Collision handled)
# Renamed 'P1110773.JPG' to '2024-10-25 14.22.08_1.jpg' (Collision handled)
# Renamed 'P1110767.JPG' to '2024-10-25 14.22.00_1.jpg' (Collision handled)
# Renamed 'P1110798.JPG' to '2024-10-25 14.23.14_1.jpg' (Collision handled)
# Renamed 'P1110607.JPG' to '2024-10-25 14.10.56.jpg'
# Renamed 'P1110613.JPG' to '2024-10-25 14.12.05_1.jpg' (Collision handled)
# Renamed 'P1110820.JPG' to '2024-10-25 15.23.50.jpg'
# Renamed 'P1110834.JPG' to '2024-10-25 15.29.20_1.jpg' (Collision handled)
# Renamed 'P1110822.JPG' to '2024-10-25 15.23.51_1.jpg' (Collision handled)
# Renamed 'P1110836.JPG' to '2024-10-25 15.29.21.jpg'
# Renamed 'P1110639.JPG' to '2024-10-25 14.12.57.jpg'
# Renamed 'P1110605.JPG' to '2024-10-25 14.10.55_1.jpg' (Collision handled)
# Renamed 'P1110611.JPG' to '2024-10-25 14.11.11.jpg'
# Renamed 'P1110759.JPG' to '2024-10-25 14.21.58.jpg'
# Renamed 'P1110771.JPG' to '2024-10-25 14.22.08_1_2.jpg' (Collision handled)
# Renamed 'P1110765.JPG' to '2024-10-25 14.21.59.jpg'
# Renamed 'P1110598.JPG' to '2024-10-25 14.10.37.jpg'
# Renamed 'P1110573.JPG' to '2024-10-25 14.09.22.jpg'
# Renamed 'P1110567.JPG' to '2024-10-25 14.09.14.jpg'
# Renamed 'P1110566.JPG' to '2024-10-25 14.09.14_1.jpg' (Collision handled)
# Renamed 'P1110572.JPG' to '2024-10-25 14.09.15_1_2.jpg' (Collision handled)
# Renamed 'P1110599.JPG' to '2024-10-25 14.10.46.jpg'
# Renamed 'P1110764.JPG' to '2024-10-25 14.21.59_1.jpg' (Collision handled)
# Renamed 'P1110770.JPG' to '2024-10-25 14.22.01.jpg'
# Renamed 'P1110758.JPG' to '2024-10-25 14.21.58_1.jpg' (Collision handled)
# Renamed 'P1110610.JPG' to '2024-10-25 14.11.11_1.jpg' (Collision handled)
# Renamed 'P1110604.JPG' to '2024-10-25 14.10.47.jpg'
# Renamed 'P1110638.JPG' to '2024-10-25 14.12.56.jpg'
# Renamed 'P1110837.JPG' to '2024-10-25 15.29.21_1.jpg' (Collision handled)
# Renamed 'P1110823.JPG' to '2024-10-25 15.23.52.jpg'
# Renamed 'P1110827.JPG' to '2024-10-25 15.29.18.jpg'
# Renamed 'P1110833.JPG' to '2024-10-25 15.29.19.jpg'
# Renamed 'P1110600.JPG' to '2024-10-25 14.10.46_1.jpg' (Collision handled)
# Renamed 'P1110614.JPG' to '2024-10-25 14.12.06.jpg'
# Renamed 'P1110628.JPG' to '2024-10-25 14.12.13.jpg'
# Renamed 'P1110774.JPG' to '2024-10-25 14.22.08_1_2_3.jpg' (Collision handled)
# Renamed 'P1110760.JPG' to '2024-10-25 14.21.58_1_2.jpg' (Collision handled)
# Renamed 'P1110748.JPG' to '2024-10-25 14.21.29.jpg'
# Renamed 'P1110589.JPG' to '2024-10-25 14.09.54.jpg'
# Renamed 'P1110576.JPG' to '2024-10-25 14.09.22_1.jpg' (Collision handled)
# Renamed 'P1110563.JPG' to '2024-10-25 14.09.06.jpg'
# Renamed 'P1110577.JPG' to '2024-10-25 14.09.23.jpg'
# Renamed 'P1110588.JPG' to '2024-10-25 14.09.54_1.jpg' (Collision handled)
# Renamed 'P1110749.JPG' to '2024-10-25 14.21.29_1.jpg' (Collision handled)
# Renamed 'P1110761.JPG' to '2024-10-25 14.21.58_1_2_3.jpg' (Collision handled)
# Renamed 'P1110775.JPG' to '2024-10-25 14.22.08_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110629.JPG' to '2024-10-25 14.12.55.jpg'
# Renamed 'P1110615.JPG' to '2024-10-25 14.12.10.jpg'
# Renamed 'P1110601.JPG' to '2024-10-25 14.10.47_1.jpg' (Collision handled)
# Renamed 'P1110832.JPG' to '2024-10-25 15.29.19_1.jpg' (Collision handled)
# Renamed 'P1110826.JPG' to '2024-10-25 15.23.54.jpg'
# Renamed 'P1110818.JPG' to '2024-10-25 15.23.50_1.jpg' (Collision handled)
# Renamed 'P1110830.JPG' to '2024-10-25 15.29.19_1_2.jpg' (Collision handled)
# Renamed 'P1110824.JPG' to '2024-10-25 15.23.53.jpg'
# Renamed 'P1110617.JPG' to '2024-10-25 14.12.10_1.jpg' (Collision handled)
# Renamed 'P1110603.JPG' to '2024-10-25 14.10.47_1_2.jpg' (Collision handled)
# Renamed 'P1110788.JPG' to '2024-10-25 14.22.39.jpg'
# Renamed 'P1110763.JPG' to '2024-10-25 14.21.59_1_2.jpg' (Collision handled)
# Renamed 'P1110777.JPG' to '2024-10-25 14.22.29.jpg'
# Renamed 'P1110561.JPG' to '2024-10-25 14.09.06_1.jpg' (Collision handled)
# Renamed 'P1110575.JPG' to '2024-10-25 14.09.22_1_2.jpg' (Collision handled)
# Renamed 'P1110549.JPG' to '2024-10-25 14.05.14.jpg'
# Renamed 'P1110548.JPG' to '2024-10-25 14.05.14_1.jpg' (Collision handled)
# Renamed 'P1110574.JPG' to '2024-10-25 14.09.22_1_2_3.jpg' (Collision handled)
# Renamed 'P1110776.JPG' to '2024-10-25 14.22.09.jpg'
# Renamed 'P1110762.JPG' to '2024-10-25 14.21.58_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110789.JPG' to '2024-10-25 14.23.12.jpg'
# Renamed 'P1110602.JPG' to '2024-10-25 14.10.47_1_2_3.jpg' (Collision handled)
# Renamed 'P1110616.JPG' to '2024-10-25 14.12.10_1_2.jpg' (Collision handled)
# Renamed 'P1110825.JPG' to '2024-10-25 15.23.53_1.jpg' (Collision handled)
# Renamed 'P1110831.JPG' to '2024-10-25 15.29.19_1_2_3.jpg' (Collision handled)
# Renamed 'P1110819.JPG' to '2024-10-25 15.23.50_1_2.jpg' (Collision handled)
# Renamed 'P1110814.JPG' to '2024-10-25 15.23.49.jpg'
# Renamed 'P1110800.JPG' to '2024-10-25 14.24.53.jpg'
# Renamed 'P1110828.JPG' to '2024-10-25 15.29.19_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110633.JPG' to '2024-10-25 14.12.55_1.jpg' (Collision handled)
# Renamed 'P1110627.JPG' to '2024-10-25 14.12.13_1.jpg' (Collision handled)
# Renamed 'P1110784.JPG' to '2024-10-25 14.22.38.jpg'
# Renamed 'P1110790.JPG' to '2024-10-25 14.23.12_1.jpg' (Collision handled)
# Renamed 'P1110747.JPG' to '2024-10-25 14.21.29_1_2.jpg' (Collision handled)
# Renamed 'P1110753.JPG' to '2024-10-25 14.21.49.jpg'
# Renamed 'P1110586.JPG' to '2024-10-25 14.09.31.jpg'
# Renamed 'P1110592.JPG' to '2024-10-25 14.09.59.jpg'
# Renamed 'P1110579.JPG' to '2024-10-25 14.09.23_1.jpg' (Collision handled)
# Renamed 'P1110545.JPG' to '2024-10-25 14.04.54.jpg'
# Renamed 'P1110551.JPG' to '2024-10-25 14.05.16.jpg'
# Renamed 'P1110550.JPG' to '2024-10-25 14.05.15.jpg'
# Renamed 'P1110544.JPG' to '2024-10-25 14.04.54_1.jpg' (Collision handled)
# Renamed 'P1110578.JPG' to '2024-10-25 14.09.23_1_2.jpg' (Collision handled)
# Renamed 'P1110593.JPG' to '2024-10-25 14.09.59_1.jpg' (Collision handled)
# Renamed 'P1110587.JPG' to '2024-10-25 14.09.31_1.jpg' (Collision handled)
# Renamed 'P1110752.JPG' to '2024-10-25 14.21.48.jpg'
# Renamed 'P1110746.JPG' to '2024-10-25 14.21.28.jpg'
# Renamed 'P1110791.JPG' to '2024-10-25 14.23.12_1_2.jpg' (Collision handled)
# Renamed 'P1110785.JPG' to '2024-10-25 14.22.38_1.jpg' (Collision handled)
# Renamed 'P1110626.JPG' to '2024-10-25 14.12.13_1_2.jpg' (Collision handled)
# Renamed 'P1110632.JPG' to '2024-10-25 14.12.55_1_2.jpg' (Collision handled)
# Renamed 'P1110829.JPG' to '2024-10-25 15.29.19_1_2_3_4_5.jpg' (Collision handled)
# Renamed 'P1110801.JPG' to '2024-10-25 14.24.54.jpg'
# Renamed 'P1110815.JPG' to '2024-10-25 15.23.49_1.jpg' (Collision handled)
# Renamed 'P1110803.JPG' to '2024-10-25 14.24.54_1.jpg' (Collision handled)
# Renamed 'P1110817.JPG' to '2024-10-25 15.23.50_1_2_3.jpg' (Collision handled)
# Renamed 'P1110618.JPG' to '2024-10-25 14.12.11.jpg'
# Renamed 'P1110624.JPG' to '2024-10-25 14.12.13_1_2_3.jpg' (Collision handled)
# Renamed 'P1110630.JPG' to '2024-10-25 14.12.55_1_2_3.jpg' (Collision handled)
# Renamed 'P1110793.JPG' to '2024-10-25 14.23.13.jpg'
# Renamed 'P1110787.JPG' to '2024-10-25 14.22.39_1.jpg' (Collision handled)
# Renamed 'P1110778.JPG' to '2024-10-25 14.22.29_1.jpg' (Collision handled)
# Renamed 'P1110750.JPG' to '2024-10-25 14.21.29_1_2_3.jpg' (Collision handled)
# Renamed 'P1110744.JPG' to '2024-10-25 14.20.52.jpg'
# Renamed 'P1110591.JPG' to '2024-10-25 14.09.59_1_2.jpg' (Collision handled)
# Renamed 'P1110585.JPG' to '2024-10-25 14.09.30.jpg'
# Renamed 'P1110552.JPG' to '2024-10-25 14.05.16_1.jpg' (Collision handled)
# Renamed 'P1110546.JPG' to '2024-10-25 14.04.54_1_2.jpg' (Collision handled)
# Renamed 'P1110547.JPG' to '2024-10-25 14.04.56.jpg'
# Renamed 'P1110584.JPG' to '2024-10-25 14.09.30_1.jpg' (Collision handled)
# Renamed 'P1110590.JPG' to '2024-10-25 14.09.54_1_2.jpg' (Collision handled)
# Renamed 'P1110745.JPG' to '2024-10-25 14.20.53.jpg'
# Renamed 'P1110751.JPG' to '2024-10-25 14.21.48_1.jpg' (Collision handled)
# Renamed 'P1110779.JPG' to '2024-10-25 14.22.29_1_2.jpg' (Collision handled)
# Renamed 'P1110786.JPG' to '2024-10-25 14.22.38_1_2.jpg' (Collision handled)
# Renamed 'P1110792.JPG' to '2024-10-25 14.23.13_1.jpg' (Collision handled)
# Renamed 'P1110631.JPG' to '2024-10-25 14.12.55_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110625.JPG' to '2024-10-25 14.12.13_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110619.JPG' to '2024-10-25 14.12.11_1.jpg' (Collision handled)
# Renamed 'P1110816.JPG' to '2024-10-25 15.23.50_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110802.JPG' to '2024-10-25 14.24.54_1_2.jpg' (Collision handled)
# Renamed 'P1110812.JPG' to '2024-10-25 15.23.49_1_2.jpg' (Collision handled)
# Renamed 'P1110621.JPG' to '2024-10-25 14.12.12.jpg'
# Renamed 'P1110635.JPG' to '2024-10-25 14.12.56_1.jpg' (Collision handled)
# Renamed 'P1110609.JPG' to '2024-10-25 14.11.11_1_2.jpg' (Collision handled)
# Renamed 'P1110796.JPG' to '2024-10-25 14.23.13_1_2.jpg' (Collision handled)
# Renamed 'P1110782.JPG' to '2024-10-25 14.22.30.jpg'
# Renamed 'P1110755.JPG' to '2024-10-25 14.21.49_1.jpg' (Collision handled)
# Renamed 'P1110741.JPG' to '2024-10-25 14.20.46_1_2.jpg' (Collision handled)
# Renamed 'P1110769.JPG' to '2024-10-25 14.22.01_1.jpg' (Collision handled)
# Renamed 'P1110594.JPG' to '2024-10-25 14.09.59_1_2_3.jpg' (Collision handled)
# Renamed 'P1110580.JPG' to '2024-10-25 14.09.24.jpg'
# Renamed 'P1110543.JPG' to '2024-10-25 14.04.31.jpg'
# Renamed 'P1110542.JPG' to '2024-10-25 14.04.31_1.jpg' (Collision handled)
# Renamed 'P1110581.JPG' to '2024-10-25 14.09.24_1.jpg' (Collision handled)
# Renamed 'P1110595.JPG' to '2024-10-25 14.10.37_1.jpg' (Collision handled)
# Renamed 'P1110768.JPG' to '2024-10-25 14.22.00_1_2.jpg' (Collision handled)
# Renamed 'P1110740.JPG' to '2024-10-25 14.20.46_1_2_3.jpg' (Collision handled)
# Renamed 'P1110754.JPG' to '2024-10-25 14.21.49_1_2.jpg' (Collision handled)
# Renamed 'P1110783.JPG' to '2024-10-25 14.22.38_1_2_3.jpg' (Collision handled)
# Renamed 'P1110797.JPG' to '2024-10-25 14.23.13_1_2_3.jpg' (Collision handled)
# Renamed 'P1110608.JPG' to '2024-10-25 14.11.11_1_2_3.jpg' (Collision handled)
# Renamed 'P1110634.JPG' to '2024-10-25 14.12.56_1_2.jpg' (Collision handled)
# Renamed 'P1110620.JPG' to '2024-10-25 14.12.11_1_2.jpg' (Collision handled)
# Renamed 'P1110813.JPG' to '2024-10-25 15.23.49_1_2_3.jpg' (Collision handled)
# Renamed 'P1110839.JPG' to '2024-10-25 15.29.22_1_2_3.jpg' (Collision handled)
# Renamed 'P1110811.JPG' to '2024-10-25 15.23.49_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110636.JPG' to '2024-10-25 14.12.56_1_2_3.jpg' (Collision handled)
# Renamed 'P1110622.JPG' to '2024-10-25 14.12.12_1.jpg' (Collision handled)
# Renamed 'P1110781.JPG' to '2024-10-25 14.22.30_1.jpg' (Collision handled)
# Renamed 'P1110795.JPG' to '2024-10-25 14.23.13_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110742.JPG' to '2024-10-25 14.20.46_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110756.JPG' to '2024-10-25 14.21.49_1_2_3.jpg' (Collision handled)
# Renamed 'P1110583.JPG' to '2024-10-25 14.09.25.jpg'
# Renamed 'P1110597.JPG' to '2024-10-25 14.10.37_1_2.jpg' (Collision handled)
# Renamed 'P1110540.JPG' to '2024-10-25 14.04.22_1_2.jpg' (Collision handled)
# Renamed 'P1110568.JPG' to '2024-10-25 14.09.15_1_2_3.jpg' (Collision handled)
# Renamed 'P1110569.JPG' to '2024-10-25 14.09.15_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110541.JPG' to '2024-10-25 14.04.31_1_2.jpg' (Collision handled)
# Renamed 'P1110596.JPG' to '2024-10-25 14.10.37_1_2_3.jpg' (Collision handled)
# Renamed 'P1110582.JPG' to '2024-10-25 14.09.24_1_2.jpg' (Collision handled)
# Renamed 'P1110757.JPG' to '2024-10-25 14.21.57.jpg'
# Renamed 'P1110743.JPG' to '2024-10-25 14.20.52_1.jpg' (Collision handled)
# Renamed 'P1110794.JPG' to '2024-10-25 14.23.13_1_2_3_4_5.jpg' (Collision handled)
# Renamed 'P1110780.JPG' to '2024-10-25 14.22.29_1_2_3.jpg' (Collision handled)
# Renamed 'P1110623.JPG' to '2024-10-25 14.12.13_1_2_3_4_5.jpg' (Collision handled)
# Renamed 'P1110637.JPG' to '2024-10-25 14.12.56_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110804.JPG' to '2024-10-25 14.24.54_1_2_3.jpg' (Collision handled)
# Renamed 'P1110810.JPG' to '2024-10-25 15.23.48.jpg'
# Renamed 'P1110838.JPG' to '2024-10-25 15.29.21_1_2.jpg' (Collision handled)
# Renamed 'P1110693.JPG' to '2024-10-25 14.17.03.jpg'
# Renamed 'P1110687.JPG' to '2024-10-25 14.16.53.jpg'
# Renamed 'P1110678.JPG' to '2024-10-25 14.16.46.jpg'
# Renamed 'P1110650.JPG' to '2024-10-25 14.13.36_1.jpg' (Collision handled)
# Renamed 'P1110644.JPG' to '2024-10-25 14.13.21.jpg'
# Renamed 'P1110718.JPG' to '2024-10-25 14.18.51_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110724.JPG' to '2024-10-25 14.19.38.jpg'
# Renamed 'P1110730.JPG' to '2024-10-25 14.20.07_1_2.jpg' (Collision handled)
# Renamed 'P1110526.JPG' to '2024-10-25 14.03.52.jpg'
# Renamed 'P1110532.JPG' to '2024-10-25 14.04.09.jpg'
# Renamed 'P1110533.JPG' to '2024-10-25 14.04.09_1.jpg' (Collision handled)
# Renamed 'P1110527.JPG' to '2024-10-25 14.03.55.jpg'
# Renamed 'P1110731.JPG' to '2024-10-25 14.20.07_1_2_3.jpg' (Collision handled)
# Renamed 'P1110725.JPG' to '2024-10-25 14.19.39.jpg'
# Renamed 'P1110719.JPG' to '2024-10-25 14.19.36.jpg'
# Renamed 'P1110645.JPG' to '2024-10-25 14.13.22.jpg'
# Renamed 'P1110651.JPG' to '2024-10-25 14.13.36_1_2.jpg' (Collision handled)
# Renamed 'P1110679.JPG' to '2024-10-25 14.16.46_1.jpg' (Collision handled)
# Renamed 'P1110686.JPG' to '2024-10-25 14.16.52.jpg'
# Renamed 'P1110692.JPG' to '2024-10-25 14.17.03_1.jpg' (Collision handled)
# Renamed 'P1110492.JPG' to '2024-10-25 14.02.53.jpg'
# Renamed 'P1110684.JPG' to '2024-10-25 14.16.52_1.jpg' (Collision handled)
# Renamed 'P1110848.JPG' to '2024-10-25 16.46.30.jpg'
# Renamed 'P1110690.JPG' to '2024-10-25 14.16.57_1_2.jpg' (Collision handled)
# Renamed 'P1110647.JPG' to '2024-10-25 14.13.22_1.jpg' (Collision handled)
# Renamed 'P1110653.JPG' to '2024-10-25 14.13.36_1_2_3.jpg' (Collision handled)
# Renamed 'P1110733.JPG' to '2024-10-25 14.20.37.jpg'
# Renamed 'P1110727.JPG' to '2024-10-25 14.20.06.jpg'
# Renamed 'P1110519.JPG' to '2024-10-25 14.03.35.jpg'
# Renamed 'P1110531.JPG' to '2024-10-25 14.04.09_1_2.jpg' (Collision handled)
# Renamed 'P1110525.JPG' to '2024-10-25 14.03.52_1.jpg' (Collision handled)
# Renamed 'P1110530.JPG' to '2024-10-25 14.03.58_1.jpg' (Collision handled)
# Renamed 'P1110518.JPG' to '2024-10-25 14.03.34_1.jpg' (Collision handled)
# Renamed 'P1110726.JPG' to '2024-10-25 14.20.06_1.jpg' (Collision handled)
# Renamed 'P1110732.JPG' to '2024-10-25 14.20.36.jpg'
# Renamed 'P1110652.JPG' to '2024-10-25 14.13.36_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110646.JPG' to '2024-10-25 14.13.22_1_2.jpg' (Collision handled)
# Renamed 'P1110691.JPG' to '2024-10-25 14.17.03_1_2.jpg' (Collision handled)
# Renamed 'P1110849.JPG' to '2024-10-25 16.54.05.jpg'
# Renamed 'P1110685.JPG' to '2024-10-25 14.16.52_1_2.jpg' (Collision handled)
# Renamed 'P1110493.JPG' to '2024-10-25 14.02.53_1.jpg' (Collision handled)
# Renamed 'P1110497.JPG' to '2024-10-25 14.03.00.jpg'
# Renamed 'P1110681.JPG' to '2024-10-25 14.16.46_1_2.jpg' (Collision handled)
# Renamed 'P1110695.JPG' to '2024-10-25 14.17.04.jpg'
# Renamed 'P1110642.JPG' to '2024-10-25 14.13.20.jpg'
# Renamed 'P1110656.JPG' to '2024-10-25 14.14.56_1_2_3.jpg' (Collision handled)
# Renamed 'P1110736.JPG' to '2024-10-25 14.20.45.jpg'
# Renamed 'P1110722.JPG' to '2024-10-25 14.19.38_1.jpg' (Collision handled)
# Renamed 'P1110534.JPG' to '2024-10-25 14.04.11.jpg'
# Renamed 'P1110520.JPG' to '2024-10-25 14.03.35_1.jpg' (Collision handled)
# Renamed 'P1110508.JPG' to '2024-10-25 14.03.11_1_2_3.jpg' (Collision handled)
# Renamed 'P1110509.JPG' to '2024-10-25 14.03.11_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110521.JPG' to '2024-10-25 14.03.35_1_2.jpg' (Collision handled)
# Renamed 'P1110535.JPG' to '2024-10-25 14.04.12.jpg'
# Renamed 'P1110723.JPG' to '2024-10-25 14.19.38_1_2.jpg' (Collision handled)
# Renamed 'P1110737.JPG' to '2024-10-25 14.20.45_1.jpg' (Collision handled)
# Renamed 'P1110657.JPG' to '2024-10-25 14.14.56_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110643.JPG' to '2024-10-25 14.13.21_1.jpg' (Collision handled)
# Renamed 'P1110694.JPG' to '2024-10-25 14.17.04_1.jpg' (Collision handled)
# Renamed 'P1110680.JPG' to '2024-10-25 14.16.46_1_2_3.jpg' (Collision handled)
# Renamed 'P1110496.JPG' to '2024-10-25 14.03.00_1.jpg' (Collision handled)
# Renamed 'P1110494.JPG' to '2024-10-25 14.02.54.jpg'
# Renamed 'P1110696.JPG' to '2024-10-25 14.17.04_1_2.jpg' (Collision handled)
# Renamed 'P1110682.JPG' to '2024-10-25 14.16.46_1_2_3_4.jpg' (Collision handled)
# Renamed 'P1110655.JPG' to '2024-10-25 14.14.55.jpg'
# Renamed 'P1110641.JPG' to '2024-10-25 14.12.57_1.jpg' (Collision handled)
# Renamed 'P1110669.JPG' to '2024-10-25 14.16.30_1_2.jpg' (Collision handled)
# Renamed 'P1110721.JPG' to '2024-10-25 14.19.37.jpg'
# Renamed 'P1110735.JPG' to '2024-10-25 14.20.45_1_2.jpg' (Collision handled)
# Renamed 'P1110523.JPG' to '2024-10-25 14.03.44.jpg'
# Renamed 'P1110537.JPG' to '2024-10-25 14.04.19.jpg'
# Renamed 'P1110522.JPG' to '2024-10-25 14.03.40.jpg'
# Renamed 'P1110708.JPG' to '2024-10-25 14.18.33_1_2_3.jpg' (Collision handled)
# Renamed 'P1110734.JPG' to '2024-10-25 14.20.37_1.jpg' (Collision handled)
# Renamed 'P1110720.JPG' to '2024-10-25 14.19.37_1.jpg' (Collision handled)
# Renamed 'P1110668.JPG' to '2024-10-25 14.16.30_1_2_3.jpg' (Collision handled)
# Renamed 'P1110640.JPG' to '2024-10-25 14.12.57_1_2.jpg' (Collision handled)
# Renamed 'P1110654.JPG' to '2024-10-25 14.14.55_1.jpg' (Collision handled)
# Renamed 'P1110683.JPG' to '2024-10-25 14.16.47.jpg'
# Renamed 'P1110697.JPG' to '2024-10-25 14.17.37_1_2_3.jpg' (Collision handled)
# Renamed 'P1110495.JPG' to '2024-10-25 14.03.00_1_2.jpg' (Collision handled)
