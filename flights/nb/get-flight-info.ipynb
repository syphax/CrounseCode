# %%
import os
import requests
# Out:
# /Users/bcc/Code/git/CrounseCode/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import requests

url = "https://booking-com15.p.rapidapi.com/api/v1/flights/searchFlightsMultiStops"

querystring = {"legs":"[{'fromId':'BOS.AIRPORT','toId':'CDG.AIRPORT','date':'2024-12-12'},{'fromId':'CDG.AIRPORT','toId':'BOS.AIRPORT','date':'2024-12-31'}]","pageNo":"1","adults":"1","children":"0,17","sort":"BEST","cabinClass":"ECONOMY","currency_code":"USD"}

headers = {
	"x-rapidapi-key": "606fb42e3emsh657da45f97552abp1c0a34jsn8643fc519309",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1728240319554, 'data': {'aggregation': {'totalCount': 1089, 'filteredTotalCount': 1089, 'stops': [{'numberOfStops': 0, 'count': 1, 'minPrice': {'currencyCode': 'AED', 'units': 7589, 'nanos': 210000000}, 'minPriceRound': {'currencyCode': 'AED', 'units': 7592, 'nanos': 300000000}}, {'numberOfStops': 1, 'count': 596, 'minPrice': {'currencyCode': 'AED', 'units': 5699, 'nanos': 700000000}, 'minPriceRound': {'currencyCode': 'AED', 'units': 5700, 'nanos': 650000000}}, {'numberOfStops': 2, 'count': 1069, 'minPrice': {'currencyCode': 'AED', 'units': 5699, 'nanos': 700000000}, 'minPriceRound': {'currencyCode': 'AED', 'units': 5700, 'nanos': 650000000}}, {'numberOfStops': 3, 'count': 1089, 'minPrice': {'currencyCode': 'AED', 'units': 5699, 'nanos': 700000000}, 'minPriceRound': {'currencyCode': 'AED', 'units': 5700, 'nanos': 650000000}}], 'airlines': [{'name': 'Aer Lingus', 'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/EI.png', 'iataC
# ...

# %%
url = "https://booking-com15.p.rapidapi.com/api/v1/flights/searchFlights"

querystring = {"fromId":"BOS.AIRPORT","toId":"CDG.AIRPORT","pageNo":"1","adults":"1","children":"0,17","sort":"BEST","cabinClass":"ECONOMY","currency_code":"USD", "departDate":"2024-12-12", "departDate":"2024-12-31"}

headers = {
	"x-rapidapi-key": "606fb42e3emsh657da45f97552abp1c0a34jsn8643fc519309",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1728240474602, 'data': {'aggregation': {'totalCount': 295, 'filteredTotalCount': 295, 'stops': [{'numberOfStops': 0, 'count': 1, 'minPrice': {'currencyCode': 'USD', 'units': 804, 'nanos': 70000000}, 'minPriceRound': {'currencyCode': 'USD', 'units': 805, 'nanos': 0}}, {'numberOfStops': 1, 'count': 188, 'minPrice': {'currencyCode': 'USD', 'units': 804, 'nanos': 70000000}, 'minPriceRound': {'currencyCode': 'USD', 'units': 805, 'nanos': 0}}, {'numberOfStops': 2, 'count': 295, 'minPrice': {'currencyCode': 'USD', 'units': 804, 'nanos': 70000000}, 'minPriceRound': {'currencyCode': 'USD', 'units': 805, 'nanos': 0}}], 'airlines': [{'name': 'Vueling', 'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/VY.png', 'iataCode': 'VY', 'count': 3, 'minPrice': {'currencyCode': 'USD', 'units': 1387, 'nanos': 380000000}}, {'name': 'Icelandair', 'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/FI.png', 'iataCode': 'FI', 'count': 7, 'minPrice'
# ...
